# %% [markdown]
# <a href="https://colab.research.google.com/github/zaw-1808/python-learning-journey/blob/main/Function.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
max ('Hello')
# Out:
# 'o'

# %%
max (3,4,4,5,5,8,10)
# Out:
# 10

# %%
Age = (2,34,44,56,78,23,21,54,39)
print (max (Age))
print (min (Age))
print("Max:", max(Age), "Min:", min(Age))
# Out:
# 78
# 2
# Max: 78 Min: 2

# %%
Dx = "Hypertension"
print (len(Dx))
# Out:
# 12

# %%
x = 3
float (x)
# Out:
# 3.0

# %%
b = 4.5
int (b)
# Out:
# 4

# %%
import math
print (math.sqrt (2))
print (math.pi*(23))
# Out:
# 1.4142135623730951
# 72.25663103256524

# %%
#BMI calculation
wt = 45 #kg
ht = 1.56 #m
print ('BMI:', wt/ (ht**2))
# Out:
# BMI: 18.49112426035503

# %%
import math
wt = 45 #kg
ht = 1.56 #m
print ('BMI is', int (wt / math.pow(ht, 2)))
# Out:
# BMI is 18

# %%
def black_forest():
    print ('Pastry')

black_forest()
# Out:
# Pastry

# %%
def a():
  print (5)
a()
# Out:
# 5

# %%
def show_name(name):
    print(name)
show_name ("Lord Z")
# Out:
# Lord Z
