# %% [markdown]
# <a href="https://colab.research.google.com/github/zaw-1808/python-learning-journey/blob/main/Day%202%20.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
a = 77
print (a)
type (a)
# Out:
# 77
# int

# %%
b = 3.4
print (b)
type(b)
# Out:
# 3.4
# float

# %%
name = 'Black Forest'
print (name)
type (name)
# Out:
# Black Forest
# str

# %%
a = 3
b = 2
print (a+b)
print (a-b)
print (a*b)
print (a/b)
print (a**b)
print (a%b)
# Out:
# 5
# 1
# 6
# 1.5
# 9
# 1

# %%
first_name = "King"
last_name = "Z"
full_name = first_name + last_name

# Concatenate
print("Full Name:", full_name)

# Repeat
print("Repeated Name:", full_name * 3)
# Out:
# Full Name: KingZ
# Repeated Name: KingZKingZKingZ

# %%
age = input()
age = int(age)  # convert string to integer
print("In 5 years, you will be", age + 5)
# Out:
# 5
# In 5 years, you will be 10

# %%
a = input()
print (a)
print ("HI ", (a))
# Out:
# Hello
# Hello
# HI  Hello
