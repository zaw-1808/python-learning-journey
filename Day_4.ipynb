# %% [markdown]
# <a href="https://colab.research.google.com/github/zaw-1808/python-learning-journey/blob/main/Day_4.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
a = 'black forest'
a[1], len (a)
a[-1], a[-4]
# Out:
# ('t', 'r')

# %%
cake = 'Tirmisu & Balck Forst'
cake [0:3], cake [:66]
# Out:
# ('Tir', 'Tirmisu & Balck Forst')

# %%
s = 'sushi'
'u' in s, 'i' in s, 'z' in s
# Out:
# (True, True, False)

# %%
a = 'Shin Sushi'
a.upper(), a.lower()
# Out:
# ('SHIN SUSHI', 'shin sushi')

# %%
x = 'black fooest'
a = x.replace ('oo', 'or')
print (a)
# Out:
# black forest

# %%
name = "Steve"
new_name = name.replace ('ev', 'ov')
print (new_name)
# Out:
# Stove

# %%
cake = 'Black forest Black forest Black forest Tiramisu Carrot cake Cheese cake Cheese cake'
cake.count ('Tiramisu')
# Out:
# 1

# %%
Dx = 'H & M due to PU underlying COL'
for Diagnosis in Dx:
  print (Diagnosis)
# Out:
# H
#
# &
#
# M
#
# d
# u
# e
#
# t
# o
#
# P
# U
#
# u
# n
# d
# e
# r
# l
# y
# i
# n
# g
#
# C
# O
# L

# %%
Dx = 'H & M due to PU underlying COL'
for Diagnosis in Dx.split():
  print (Diagnosis)
# Out:
# H
# &
# M
# due
# to
# PU
# underlying
# COL

# %%
Dx = '    Diabetes Mellitus, Hypertension          '
Dx.rstrip()
Dx.lstrip()
Dx.strip()
# Out:
# 'Diabetes Mellitus, Hypertension'
