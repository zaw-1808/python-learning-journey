# %% [markdown]
# <a href="https://colab.research.google.com/github/zaw-1808/python-learning-journey/blob/main/Conditional_.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
5==5
# Out:
# True

# %%
4==6
# Out:
# False

# %%
type (True)
type (False)
# Out:
# bool

# %%
5>4
# Out:
# True

# %%
'Sleep' == 'Sleep'
# Out:
# True

# %%
3!=2
# Out:
# True

# %%
#Conditional execution
a = 4
if a >2 :
  print ('correct')
# Out:
# correct

# %%
#Alternative execution
b = 2
if b < 1 :
  print ('correct')
else:
  print ('wrong')
# Out:
# wrong

# %%
#Chained conditionals
Body_temp = 39
if Body_temp > 38:
   print ('Fever')
elif Body_temp == 37:
   print ('Normal')
elif Body_temp == 37.5:
   print ('Feverish')
else:
   print ('Bad')
# Out:
# Fever

# %%
#Chained conditionals
Body_temp = 30
if Body_temp > 38:
   print ('Fever')
elif Body_temp == 37:
   print ('Normal')
elif Body_temp == 37.5:
   print ('Feverish')
else:
   print ('Bad')
# Out:
# Bad

# %%
#Chained conditionals
Body_temp = 37.5

if Body_temp > 38:
    print("Fever")
elif Body_temp >= 37 and Body_temp <= 38:
    print("Feverish")
else:
    print("Normal")
# Out:
# Feverish

# %%
#Nested conditionals
BMI = 26
Age = 20
if BMI > 25:
  print ('Overweight')

  if Age > 30:
    print ('Obeses')
  else:
    print ('ow')
else:
  print ('Normal')
# Out:
# Overweight
# ow
